# %% [markdown]
# # JSON-Datenanalysen
#
# Datenquelle sind die Metadaten zu *Views of Berlin* (<https://lab.sbb.berlin/views-of-berlin/>) der Staatsbibliothek zu Berlin.
# Diese liegen als JSON vor.

# %% [markdown]
# ## Zahl der Datensätze
#
# > Die JSON-Datei berlinansichten_211028.json beginnt folgendermaßen:
# >
# > {'name': 'Berlin-Ansichten',
#  'creationDate': '2021-10-28',
#  'payload': [{'id': '1',
#    'title': 'An der Jannowitzbrücke.',
#    'special_locations': ['berlin',
#     'brueckenstrasse',
#     'jannowitzbruecke',
#     'luisenstadt',
#     'neanderstrasse',
#     'stadtbahnhof jannowitzbruecke',
#     'stralauer viertel',
#     'zweite aktienbruecke'],
#    'description': 'Von der Waisenbrücke gesehen. Links Stadtbahnhof Jannowitzbrücke. Brücke entstand als Zweite Aktienbrücke 1822, gleichzeitig wurde die Neanderstraße zur Verbindung mit dem Stralauer Viertel angelegt. 1881-83 entstand der Neubau aus Stein.',
#    'image_number': ['Bild218.jpg'],
#    'author': 'Schwartz, Friedrich Albert (1836-1906), Hofphotograph, Fotograf',
#    'place_year': 'Berlin: 1888',
#    'shelf_locator': 'gr.2°Y44252-218',
#    'format': '26 x 18,5 cm',
#    'medium_type': 'Fotografie : einfarbig',
#    'collection_number': 'Schwartz, Friedrich Albert: Ansichten aus Berlin; 218',
#    'district_old': 'Berlin. Ehem. Stralauer Viertel/ Luisenstadt.',
#    'notes': ['Quelle: Fotoatelier Schwartz. Datierung nach Zugangsjournal der Königlichen Bibliothek.'],
#    'place': 'Berlin',
#    'year_acquisition': '1888',
#    'year_recording': 'vor 1888',
#    'image_url': ['https://labcontent.sbb.berlin/berlinansichten/bilder/Bild218.jpg']},
#   {'id': '10',
#    'title': 'Das Landratsamt Ecke Jerusalemer- und Schützenstraße (war das Landrathsamt des Teltower Kreises, das nachher nach der Victoriastr. 18 verlegt```
# >
# > Schreib einen Python-Schnipsel, der die Zahl der unterschiedlichen Datensätze unter 'payload' ausgibt.

# %% [markdown]
# ## Visualisierung der Maße
#
# > Schreib einen Python-Schnipsel, der die Angaben unter "Format" als Scatter-Plot ausgibt. Bei 'format': '26 x 18,5 cm' sollte z.B. 26 als Breitenangabe auf der X-Achse, 18.5 als Höhenangabe auf der y-Achse stehen.
